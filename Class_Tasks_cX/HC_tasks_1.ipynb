# %% [markdown]
# <a href="https://colab.research.google.com/github/UKD1211/DataScience_Slogbook_ISI_placement_prep/blob/main/HC_tasks_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def age(num):
  if num < 13:
    return "child"
  elif num >= 13 and num <=19:
    return "teenager"
  elif num >= 20 and num <=59:
    return "Adult"
  else:
    return "senior"
age(5)
# Out:
# 'child'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def ticketPrice(age):
  if age<13:
    return "ticket price: $8"
  elif age>= 13 and age <= 19:
    return "ticket price: $10"
  elif age >= 20 and age <= 59:
    return "ticket price: $12"
  else:
    return "ticket price: $6"
ticketPrice(18)
# Out:
# 'ticket price: $10'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def password(string):
  if len(string) < 6:
    return "weak password"
  elif len(string) >= 6 and len(string) <= 10:
    return "medium password"
  else:
    return "Strong password"

password("ekl")
# Out:
# 'weak password'

# %%
def leap_year(year):
    if year % 400 == 0:
        return "Leap Year"
    elif year % 100 == 0:
        return "Not a Leap Year"
    elif year % 4 == 0:
        return "Leap Year"
    else:
        return "Not a Leap Year"

# Examples
print(leap_year(2020))  # Leap Year
print(leap_year(2021))  # Not a Leap Year
print(leap_year(2000))  # Leap Year
print(leap_year(1900))  # Not a Leap Year
# Out:
# Leap Year
# Not a Leap Year
# Leap Year
# Not a Leap Year

# %% [markdown]
# ![image.png](data:image/png;base64,...)
