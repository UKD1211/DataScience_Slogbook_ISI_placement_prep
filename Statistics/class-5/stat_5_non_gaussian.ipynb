# %% [markdown]
# <a href="https://colab.research.google.com/github/UKD1211/DataScience_Slogbook_ISI_placement_prep/blob/main/stat_5_non_gaussian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.kdeplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
temp = sorted(df['sepal_length'].tolist())

# %%
y_quant = []

for i in range(1,101):
  y_quant.append(np.percentile(temp,i))

# %%
y_quant
# Out:
# [np.float64(4.4),
#  np.float64(4.4),
#  np.float64(4.547),
#  np.float64(4.6),
#  np.float64(4.6),
#  np.float64(4.694),
#  np.float64(4.743),
#  np.float64(4.8),
#  np.float64(4.8),
#  np.float64(4.8),
#  np.float64(4.9),
#  np.float64(4.9),
#  np.float64(4.9),
#  np.float64(4.9),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.0),
#  np.float64(5.029),
#  np.float64(5.1),
#  np.float64(5.1),
#  np.float64(5.1),
#  np.float64(5.1),
#  np.float64(5.1),
#  np.float64(5.123),
#  np.float64(5.2),
#  np.float64(5.2),
#  np.float64(5.27),
#  np.float64(5.4),
#  np.float64(5.4),
#  np.float64(5.4),
#  np.float64(5.4),
#  np.float64(5.5),
#  np.float64(5.5),
#  np.float64(5.5),
#  np.float64(5.5),
#  np.float64(5.511),
#  np.float64(5.6),
#  np.float64(5.6),
#  np.float64(5.6),
#  np.float64(5.606999999999999),
#  np.float64(5.7),
#  np.float64(5.7),
#  np.float64(5.7),
#  np.float64(5.7),
#  np.float64(5.7),
#  np.float64(5.8),
#  np.float64(5.8),
#  np.float64(5.8),
#  np.float64(5.8),
#  np.float64(5.8),
#  np.float64(5.9),
#  np.float64(5.9),
#  np.float64(6.0),
#  np.float64(6.0),
#  np.float64(6.0),
#  np.float64(6.0),
#  np.float64(6.1),
#  np.float64(6.1),
#  np.float64(6.1),
#  np.float64(6.1),
#  np.float64(6.2),
#  np.float64(6.2),
#  np.float64(6.234),
#  np.float64(6.3),
#  np.float64(6.3),
#  np.float64(6.3),
#  np.float64(6.3),
#  np.float64(6.3),
#  np.float64(6.328),
#  np.float64(6.4),
#  np.float64(6.4),
#  np.float64(6.4),
#  np.float64(6.4),
#  np.float64(6.473000000000001),
#  np.float64(6.5),
#  np.float64(6.5),
#  np.float64(6.5200000000000005),
#  np.float64(6.6),
#  np.float64(6.7),
#  np.float64(6.7),
#  np.float64(6.7),
#  np.float64(6.7),
#  np.float64(6.7),
#  np.float64(6.763),
#  np.float64(6.8),
#  np.float64(6.8610000000000015),
#  np.float64(6.9),
#  np.float64(6.9),
#  np.float64(7.008000000000001),
#  np.float64(7.156999999999999),
#  np.float64(7.2),
#  np.float64(7.254999999999998),
#  np.float64(7.407999999999999),
#  np.float64(7.6530000000000005),
#  np.float64(7.7),
#  np.float64(7.7),
#  np.float64(7.9)]

# %%
samples = np.random.normal(loc=0,scale=1,size=1000)  #sample normal data geenrates

# %%
x_quant = []

for i in range(1,101):
  x_quant.append(np.percentile(samples,i))

# %%
sns.scatterplot(x=x_quant,y=y_quant)
# Out:
# <Axes: >

# %%
plt.scatter(x_quant,y_quant)

# %%
## using the statsmodel

import statsmodels.api as sm
import matplotlib.pyplot as plt

#create a QQ plot of the 2 sets of the data
fig = sm.qqplot(df['sepal_length'], line='45', fit=True)

plt.title('QQ plot')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('sample Values')


plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Generate a set of random data
x = np.random.uniform(low=0, high=1, size=1000)

# %%
plt.hist(x)
# Out:
# (array([ 72., 106., 117., 104., 103., 114.,  90., 100., 107.,  87.]),
#  array([6.65355277e-04, 1.00282581e-01, 1.99899807e-01, 2.99517033e-01,
#         3.99134259e-01, 4.98751485e-01, 5.98368711e-01, 6.97985937e-01,
#         7.97603162e-01, 8.97220388e-01, 9.96837614e-01]),
#  <BarContainer object of 10 artists>)

# %%
# Fit a uniform distribution to the data
params = stats.uniform.fit(x)
dist = stats.uniform(loc=params[0], scale=params[1])

# %%
# Create a QQ plot of the data using the uniform distribution
fig = sm.qqplot(x, dist=dist, line='45')

# Add a title and labels to the plot
plt.title('QQ Plot of Uniform Distribution with Uniform Fit')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')

# Show the plot
plt.show()

# %%
# Log Log Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters of the Pareto distribution
alpha = 3
xm = 1

# Create an array of x values
x = np.linspace(0.1, 10, 1000)

# Calculate the y values of the Pareto distribution
y = alpha * (xm**alpha) / (x**(alpha+1))


plt.plot(x,y)

# %%
# Create the log-log plot
plt.plot(np.log(x),np.log(y))

# Add labels and a title
plt.xlabel('x')
plt.ylabel('P(x)')
plt.title('Pareto distribution')

# Show the plot
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Define the parameters of the Pareto distribution
alpha = 2
xm = 1

# Generate a set of random data from the Pareto distribution
x = stats.pareto.rvs(b=alpha, scale=xm, size=1000)

# %%
plt.hist(x)
# Out:
# (array([988.,   7.,   2.,   0.,   0.,   0.,   1.,   0.,   1.,   1.]),
#  array([ 1.0006398 ,  7.73270199, 14.46476417, 21.19682636, 27.92888854,
#         34.66095073, 41.39301291, 48.1250751 , 54.85713728, 61.58919947,
#         68.32126165]),
#  <BarContainer object of 10 artists>)

# %%
# Fit a Pareto distribution to the data
params = stats.pareto.fit(x, floc=0)

# Create a Pareto distribution object with the fitted parameters
dist = stats.pareto(b=params[0], scale=params[2])

# %%
# Create a QQ plot of the data using the Pareto distribution
fig = sm.qqplot(x, dist=dist, line='45')

# Add a title and labels to the plot
plt.title('QQ Plot of Pareto Distribution with Pareto Fit')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')

# Show the plot
plt.show()
