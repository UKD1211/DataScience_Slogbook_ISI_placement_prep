# %% [markdown]
# <a href="https://colab.research.google.com/github/UKD1211/DataScience_Slogbook_ISI_placement_prep/blob/main/OOP_S1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = [1,2,4]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2224866345.py in <cell line: 0>()
#       1 L = [1,2,4]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello'
s.append('x')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-666329863.py in <cell line: 0>()
#       1 s = 'hello'
# ----> 2 s.append('x')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# Every thing in python is a object

# %%
#OOP gives the power to the programmer to make his own datatype

# %%
# oop has certain principles - class,object,encapsulation,inheritance,abstraction,polymorphism

# %%
L = [1,2,4]
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3930800027.py in <cell line: 0>()
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# class is a blueprint
# in python all the datatypes are class here, means all the rules are written inside the class , and
# we are making any variables from those datatypes are part of class , called object
# class is a set of rules those objects follows
# here list is a class , and  l = [1,2,3] l is a object in list class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# if we write a class on car what will be the datas there? --> color,bodytype,topspeed,milage
#  function -> calculate avg speed,
# in a class there is always data, or functions, or both

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#syntax to create an object

# objectname = classname()


# object literal
L = [1,2,4]

# %%
# else we can also create list by that

L = list()
L
# Out:
# []

# %%
s = str()
s
# Out:
# ''

# %%
# class naming

# pascal case

# 'HelloWorld'

# %%
class Atm:

  #constructor->function inside the class
  # its a special function - it has a superpower
  # as to work this constructor code will not to call the function , it will work by its object
  def __init__(self):
    # print(id(self))
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input =  input("""
    hi how can i help you
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      #create_pin
      self.create_pin()
    elif user_input == '2':
      #change pin
      self.change_pin()
    elif user_input == '3':
      #check balance
      self.check_balance()
      pass
    elif user_input == '4':
      #withdraw
      self.withdraw()
      pass
    else:
      exit()



  def create_pin(self):
    user_pin = input("enter your pin")
    self.pin = user_pin

    user_balance = int(input('enter your balance also'))
    self.balance = user_balance

    print('pin created succesfully')
    self.menu()


  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      #change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin changed successfully')
      self.menu()
    else:
      print('you entered wrong pin')
      self.menu()


  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',int(self.balance))
    else:
      print('you entered wrong pin')
    self.menu()

  def withdraw(self):
    amount = int(input('please enter the amount u want'))
    user_pin = input('enter your pin')
    if user_pin == self.pin and amount <= int(self.balance):

      print(f"amount withdraw successful {amount}")
      self_balance = self.balance - int(amount)
      print(self_balance)
      self.menu()
    else:
      print("erite correct pin")
      self.menu()

# %%
obj = Atm()   # when we will create the object it will automaticaaly trigger the Atm class constructor
# Out:
# 135779123706576

# %%
print(id(obj))
# Out:
# 135779123706576

# %%
obj2 = Atm()
# Out:
# execute ho gaya

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %%
#python has 2 types of classes ---> built in classes & user defined classes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Method --> if any functions are inside the class then we will call it methods
# if any function is independent utside the class - function

# %%
 L = [1,2,3]
 print(len(L))   #here len() is the function as its outside the class list
 L.append(4)     #here append() is the method as its ind=side the class list
# Out:
# 3

# %% [markdown]
# # **Class Diagram**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# magic methods or dunder methods

# %%
# magic methods is a special method --> super power
# __name__ = name construction here--> like __inint__ -> constructor
# __init__ has the super power here
# by using the magic methods we can create our own datatypes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# What is constructor?
#  --> it is a method and it got a superpower, its a special/magic method
#  we dont need need to call this method, it automatically triggers when object created

# %%
# Adv? / benefit of using it ?

# %%
class Temp:

  def __init__(self):
    print("hello")
obj  = Temp()
# Out:
# hello

# %% [markdown]
# # Constructor is needed to write configuration related codes, like database connection,internet conncetion, as constructor is the only part which dont give the control to the customer, it triggers itself

# %%
# IF GOD IS THE PROGRAMMER , AND EARTH IS THE CLASS, AND HUMANS ARE THE OBJECTS, THEN IN CONSTRUCTOR THE
# FUNCTION OF DEATH IS DEFINED BY GOD,when ever someone born it ensures that he wil die for sure

# %%
# self is getting used in many places but why ?

# %%
# class has data/attributes and methods, and only that classes object can get the access of those attributes nad methods

# %% [markdown]
# # **Golden Rule of OOP: class ke andar ke functions ko sirf object ofthe class access kar sakta hai**

# %%
# so even any method cant call the other method in a class, thats why SELF needed which will call them
# self helps other methods to call another methods

# %% [markdown]
# #From above we saw that the self -> object it self

# %% [markdown]
# # self is nothing but the current object , but why?
# # as in oop the golden rule anyone cannot call anymethod that called another one , only object can access the functions or methods, thats why self is neede

# %%
# OWN DATA TYPE

# %%
class Fraction:

  # parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __mul__(self,other):
    new_num = self.num*other.num
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den*other.num

    return '{}/{}'.format(new_num,new_den)

  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1 = Fraction(3,4)  #here when ever we have to make a object we have to provide the parameters
fr2 = Fraction(1,2)

# %%
print(type(fr1))
# Out:
# <class '__main__.Fraction'>

# %%
print(fr1) #here the computer doesnt know about the how this fraction will looks like
print(fr2)
# Out:
# 3/4
# 1/2

# %%
print(fr1 + fr2)
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
# Out:
# 10/8
# 2/8
# 3/8
# 6/4

# %%
s1={1,2,3}
s2={3,4,5}

s1 + s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3046025221.py in <cell line: 0>()
#       2 s2={3,4,5}
#       3
# ----> 4 s1 + s2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'
